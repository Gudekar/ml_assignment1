# %%
#Assignment: Select any public Dataset from Kaggle/Github and apply Simple linear regression

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('test.csv')
data
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       300 non-null    int64
#  1   y       300 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.8 KB

# %%
plt.scatter(data.x,data.y,color='red')

# %%
#seperate input
inp=data[['x']]
inp[:5]
# Out:
#     x
# 0  77
# 1  21
# 2  22
# 3  20
# 4  36

# %%
#seperate output
out= data['y']
out[:5]
# Out:
# 0    79.775152
# 1    23.177279
# 2    25.609262
# 3    17.857388
# 4    41.849864
# Name: y, dtype: float64

# %%
#training phase
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(inp,out)
# Out:
# LinearRegression()

# %%
model.score(inp,out)*100
# Out:
# 98.91203611402716

# %%
#testing phase
model.predict([[72]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72.57033479])

# %%
#m
model.coef_
# Out:
# array([1.01433536])

# %%
#c
model.intercept_
# Out:
# -0.4618107736611847

# %%
model.predict([[17]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16.78189026])

# %%
#create test input data
test=data.sample(50)
test
# Out:
#        x           y
# 164   49   52.286206
# 12    96   95.149072
# 55     0   -1.040114
# 80    68   70.369875
# 42    50   50.961555
# 47    68   65.013240
# 119    0   -3.467884
# 258   67   63.807682
# 233   91   89.739520
# 115   24   25.634763
# 78    52   52.019323
# 201   26   25.756125
# 81    27   23.444792
# 21    51   46.913877
# 176   58   57.487414
# 99    32   33.384741
# 266   76   79.503415
# 249   38   36.941732
# 95    14   13.839599
# 272   56   56.014481
# 49    35   34.311414
# 68    55   51.835039
# 207   77   79.314255
# 29    27   26.591124
# 194   61   60.071375
# 270   55   55.816285
# 183   91   91.692407
# 11    19   17.095372
# 0     77   79.775152
# 102   19   17.440476
# 20    89   92.119063
# 245   31   24.184380
# 146   99   98.030177
# 147   60   63.193544
# 129   29   26.494880
# 171   37   40.035049
# 267   34   34.588765
# 268   55   55.738347
# 290   92   91.308637
# 215   55   51.800359
# 299   47   52.459467
# 154   63   61.740632
# ...

# %%
test_in=test[['x']]
test_in
test_out=test[['y']]
test_out
# Out:
#               y
# 164   52.286206
# 12    95.149072
# 55    -1.040114
# 80    70.369875
# 42    50.961555
# 47    65.013240
# 119   -3.467884
# 258   63.807682
# 233   89.739520
# 115   25.634763
# 78    52.019323
# 201   25.756125
# 81    23.444792
# 21    46.913877
# 176   57.487414
# 99    33.384741
# 266   79.503415
# 249   36.941732
# 95    13.839599
# 272   56.014481
# 49    34.311414
# 68    51.835039
# 207   79.314255
# 29    26.591124
# 194   60.071375
# 270   55.816285
# 183   91.692407
# 11    17.095372
# 0     79.775152
# 102   17.440476
# 20    92.119063
# 245   24.184380
# 146   98.030177
# 147   63.193544
# 129   26.494880
# 171   40.035049
# 267   34.588765
# 268   55.738347
# 290   91.308637
# 215   51.800359
# 299   52.459467
# 154   61.740632
# 134   29.317700
# 87   105.591837
# 260   16.828397
# 41    68.167248
# 177   36.062930
# 206   48.098431
# 23    21.713803
# 70    46.561418

# %%
test_pred=model.predict(test_in)
test_pred
# Out:
# array([ 49.24062163,  96.91438332,  -0.46181077,  68.51299337,
#         50.25495698,  68.51299337,  -0.46181077,  67.49865802,
#         91.84270654,  23.88223775,  52.28362769,  25.91090846,
#         26.92524381,  51.26929234,  58.36963982,  31.99692059,
#         76.62767622,  38.08293272,  13.7388842 ,  56.34096911,
#         35.03992666,  55.32663376,  77.64201157,  26.92524381,
#         61.41264589,  55.32663376,  91.84270654,  18.81056097,
#         77.64201157,  18.81056097,  89.81403583,  30.98258524,
#         99.95738938,  60.39831053,  28.95391452,  37.06859737,
#         34.0255913 ,  55.32663376,  92.8570419 ,  55.32663376,
#         47.21195092,  63.4413166 ,  27.93957917, 100.97172474,
#         15.76755491,  71.55599944,  31.99692059,  40.11160343,
#         26.92524381,  46.19761556])

# %%
# plot training and testing result
plt.scatter(data.x,data.y,color='red',label='Data points')
plt.plot(test_in,test_pred,'k--',label='best fit line')
plt.legend()

# %%
#measure the performance of ML model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
test_out,test_pred
# Out:
# (              y
#  164   52.286206
#  12    95.149072
#  55    -1.040114
#  80    70.369875
#  42    50.961555
#  47    65.013240
#  119   -3.467884
#  258   63.807682
#  233   89.739520
#  115   25.634763
#  78    52.019323
#  201   25.756125
#  81    23.444792
#  21    46.913877
#  176   57.487414
#  99    33.384741
#  266   79.503415
#  249   36.941732
#  95    13.839599
#  272   56.014481
#  49    34.311414
#  68    51.835039
#  207   79.314255
#  29    26.591124
#  194   60.071375
#  270   55.816285
#  183   91.692407
#  11    17.095372
#  0     79.775152
#  102   17.440476
#  20    92.119063
#  245   24.184380
#  146   98.030177
#  147   63.193544
#  129   26.494880
#  171   40.035049
#  267   34.588765
#  268   55.738347
#  290   91.308637
#  215   51.800359
#  299   52.459467
#  154   61.740632
#  134   29.317700
#  87   105.591837
#  260   16.828397
#  41    68.167248
#  177   36.062930
#  206   48.098431
#  23    21.713803
#  70    46.561418,
# ...

# %%
mean_absolute_error(test_out,test_pred)
# Out:
# 2.2145056314329854

# %%
mean_squared_error(test_out,test_pred)
# Out:
# 7.93649801353347

# %%
r2_score(test_out,test_pred)
# Out:
# 0.9885800270730541
